# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ds = pd.read_csv(r'../Lecture_4/titanic.csv')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
cols_to_drop = [
    'PassengerId',
    'Name',
    'Ticket',
    'Cabin',
    'Embarked',
]

df = ds.drop(cols_to_drop, axis=1)
df.head()

#Usual Way
# df = ds.drop(["PassengerId","Name","Ticket","Cabin","Embarked"], axis = 1)
# df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
def convert_sex_to_num(s):
    if s=='male':
        return 0
    elif s=='female':
        return 1
    else:
        return s

df.Sex = df.Sex.map(convert_sex_to_num)
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0         0       3    0  22.0      1      0   7.2500
# 1         1       1    1  38.0      1      0  71.2833
# 2         1       3    1  26.0      0      0   7.9250
# 3         1       1    1  35.0      1      0  53.1000
# 4         0       3    0  35.0      0      0   8.0500

# %%
data = df.dropna()
# data.describe()

data.shape[0]
# Out:
# 714

# %%
# data2 = data[:10]
# print(data2)
# data2.Survived.mean()

# %%
plt.figure()
sns.heatmap(data.corr())

# %%
input_cols = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']
out_cols = ['Survived']

X = data[input_cols]
y = data[out_cols]

#X.head()
print(X.shape, y.shape)
# Out:
# (714, 6) (714, 1)

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare
# 0           0       3    0  22.0      1      0    7.2500
# 1           1       1    1  38.0      1      0   71.2833
# 2           1       3    1  26.0      0      0    7.9250
# 3           1       1    1  35.0      1      0   53.1000
# 4           0       3    0  35.0      0      0    8.0500
# 5           0       1    0  54.0      0      0   51.8625
# 6           0       3    0   2.0      3      1   21.0750
# 7           1       3    1  27.0      0      2   11.1333
# 8           1       2    1  14.0      1      0   30.0708
# 9           1       3    1   4.0      1      1   16.7000
# 10          1       1    1  58.0      0      0   26.5500
# 11          0       3    0  20.0      0      0    8.0500
# 12          0       3    0  39.0      1      5   31.2750
# 13          0       3    1  14.0      0      0    7.8542
# 14          1       2    1  55.0      0      0   16.0000
# 15          0       3    0   2.0      4      1   29.1250
# 16          0       3    1  31.0      1      0   18.0000
# 17          0       2    0  35.0      0      0   26.0000
# 18          1       2    0  34.0      0      0   13.0000
# 19          1       3    1  15.0      0      0    8.0292
# 20          1       1    0  28.0      0      0   35.5000
# 21          0       3    1   8.0      3      1   21.0750
# 22          1       3    1  38.0      1      5   31.3875
# 23          0       1    0  19.0      3      2  263.0000
# 24          0       1    0  40.0      0      0   27.7208
# 25          0       2    0  66.0      0      0   10.5000
# 26          0       1    0  28.0      1      0   82.1708
# 27          0       1    0  42.0      1      0   52.0000
# 28          0       3    0  21.0      0      0    8.0500
# 29          0       3    1  18.0      2      0   18.0000
# ..        ...     ...  ...   ...    ...    ...       ...
# 684         1       1    1  45.0      1      1  164.8667
# 685         1       1    0  51.0      0      0   26.5500
# 686         1       3    1  24.0      0      3   19.2583
# 687         0       3    0  41.0      2      0   14.1083
# 688         0       2    0  21.0      1      0   11.5000
# 689         1       1    1  48.0      0      0   25.9292
# 690         0       2    0  24.0      0      0   13.0000
# 691         1       2    1  42.0      0      0   13.0000
# 692         1       2    1  27.0      1      0   13.8583
# 693         0       1    0  31.0      0      0   50.4958
# 694         1       3    0   4.0      1      1   11.1333
# 695         0       3    0  26.0      0      0    7.8958
# 696         1       1    1  47.0      1      1   52.5542
# 697         0       1    0  33.0      0      0    5.0000
# 698         0       3    0  47.0      0      0    9.0000
# 699         1       2    1  28.0      1      0   24.0000
# 700         1       3    1  15.0      0      0    7.2250
# 701         0       3    0  20.0      0      0    9.8458
# 702         0       3    0  19.0      0      0    7.8958
# 703         1       1    1  56.0      0      1   83.1583
# 704         1       2    1  25.0      0      1   26.0000
# 705         0       3    0  33.0      0      0    7.8958
# 706         0       3    1  22.0      0      0   10.5167
# 707         0       2    0  28.0      0      0   10.5000
# 708         0       3    0  25.0      0      0    7.0500
# 709         0       3    1  39.0      0      5   29.1250
# 710         0       2    0  27.0      0      0   13.0000
# 711         1       1    1  19.0      0      0   30.0000
# 712         1       1    0  26.0      0      0   30.0000
# 713         0       3    0  32.0      0      0    7.7500
#
# [714 rows x 7 columns]

# %% [markdown]
# # Decision Tree and Random Forest Using Scikit-Learn

# %%
import sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
split = int(0.8 * data.shape[0])

training_data = data[:split]
testing_data = data[split:]

# %%
DT = DecisionTreeClassifier()
DT.fit(X[:split], y[:split])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
DT.score(X[split:], y[split:])
# Out:
# 0.7762237762237763

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X[:split], y[:split])

rf.score(X[split:], y[split:])
# Out:
# /home/bipinkalra/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.8531468531468531
